# %%
import sys
sys.path.append("/Users/bubble/Desktop/Project/T_sensor/T_sensor")
sys.path.append("/Users/bubble/Desktop/Project/T_sensor/T_sensor/chip/chip_design_3")

import import_ipynb

import gdsfactory as gf

from chip.chip_design_3.cell_web_design import create_simulation_structure as simu_web
from chip.chip_design_3.cell_web_design_circle import create_simulation_structure as simu_web_circle
from chip.chip_design_3.cell_mesh_design import create_simulation_structure as simu_mesh
from chip.chip_design_3.cell_mesh_design_less import create_simulation_structure as simu_mesh_less
# Out:
# 2026-05-28 10:57:34.834 | INFO     | kfactory.kcell:show:8783 - klive v0.3.3: Reloaded file '/Users/bubble/Desktop/Project/T_sensor/T_sensor/build/gds/1034001929.oas'

# %%
cell_web_design = simu_web()
cell_web_design.show()

# %%
cell_web_design = simu_web()
cell_web_design.write_gds("cell_web_design.gds", write_context_info=False, with_metadata=False)
cell_web_design_circle = simu_web_circle()
cell_web_design_circle.write_gds("cell_web_design_circle.gds", write_context_info=False, with_metadata=False)
cell_mesh_design = simu_mesh()
cell_mesh_design.write_gds("cell_mesh_design.gds", write_context_info=False, with_metadata=False)
cell_mesh_design_less = simu_mesh_less()
cell_mesh_design_less.write_gds("cell_mesh_design_less.gds", write_context_info=False, with_metadata=False)
# Out:
# /var/folders/c8/hfxc4xq534j9_8cwmvcnw5lm0000gn/T/ipykernel_20432/3564616334.py:2: DeprecationWarning: write_context_info is deprecated. It will be removed in 9.0.0.
#   cell_web_design.write_gds("cell_web_design.gds", write_context_info=False, with_metadata=False)
# /var/folders/c8/hfxc4xq534j9_8cwmvcnw5lm0000gn/T/ipykernel_20432/3564616334.py:4: DeprecationWarning: write_context_info is deprecated. It will be removed in 9.0.0.
#   cell_web_design_circle.write_gds("cell_web_design_circle.gds", write_context_info=False, with_metadata=False)
# /var/folders/c8/hfxc4xq534j9_8cwmvcnw5lm0000gn/T/ipykernel_20432/3564616334.py:6: DeprecationWarning: write_context_info is deprecated. It will be removed in 9.0.0.
#   cell_mesh_design.write_gds("cell_mesh_design.gds", write_context_info=False, with_metadata=False)
# /var/folders/c8/hfxc4xq534j9_8cwmvcnw5lm0000gn/T/ipykernel_20432/3564616334.py:8: DeprecationWarning: write_context_info is deprecated. It will be removed in 9.0.0.
# ...
