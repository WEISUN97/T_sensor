# %%
import sys
# sys.path.append("/Users/bubble/Desktop/Project/Infrasound Sensor/Layout/Code/acousticsensor")
from mid_structure_square import create_mid_structure_circle

import math
import gdsfactory as gf
cell_temp = gf.Component()
# the whole chip
block = gf.Component()

# %%
# web mesh
mesh_web = gf.Component()
L = 1000
w = 2
g = 48

n_horizontal = 20
for i in range(20):
    h_horizontal = 300+i*50
    L_horizontal = 2*h_horizontal*math.tan(22.5*math.pi/180)
    s_horizontal = gf.Section(width=2, layer=(9, 0))
    X_horizontal = gf.CrossSection(sections=[s_horizontal])
    p_horizontal = gf.path.straight(L_horizontal)
    c_horizontal = gf.path.extrude(p_horizontal, X_horizontal)
    (mesh_web << c_horizontal).move((-L_horizontal/2, -h_horizontal))
    (mesh_web << c_horizontal).move((-L_horizontal/2, h_horizontal)).rotate(angle=45, center=(0, 0))

n_support = 5
for i in range(n_support):
    angle = 45/4*i-22.5
    L_support_1 = 1010/math.cos(angle*math.pi/180)
    L_support_2 = 950/math.cos(angle*math.pi/180)
    s_support = gf.Section(width=2, layer=(9, 0))
    X_support = gf.CrossSection(sections=[s_support])
    p_support = gf.path.straight(L_support_1)
    c_support_1 = gf.path.extrude(p_support, X_support)
    (mesh_web << c_support_1).rotate(-90).movey(-300/math.cos(angle*math.pi/180)).rotate(angle=angle, center=(0,0))
    p_support = gf.path.straight(L_support_2)
    c_support_2 = gf.path.extrude(p_support, X_support)
    (mesh_web << c_support_2).rotate(-90).movey(-300/math.cos(angle*math.pi/180)).rotate(angle=angle+45, center=(0,0))
# circle array
for i in range(4):
    angle = 360/4*i
    (block << mesh_web).rotate(angle=angle, center=(0, 0))
# length mark
T = gf.components.text(f"L={L} b={w} gap={g}", size=50, layer=(1, 0))
(block << T).move((-375, -1500))

# block.show()
# Out:
# Unnamed_57: ports [], vinsts=[] info=Info() kcl=KCLayout(name='DEFAULT', layout=<klayout.dbcore.Layout object at 0x110438650>, layer_enclosures=LayerEnclosureModel(root={'c8fba417': LayerEnclosure(layer_sections={}, main_layer=12/0, yaml_tag='!Enclosure'), '56396fc8': LayerEnclosure(layer_sections={}, main_layer=SLAB90 (3/0), yaml_tag='!Enclosure')}), cross_sections={'c8fba417_2600000': SymmetricalCrossSection(width=2600000, enclosure=LayerEnclosure(layer_sections={}, main_layer=12/0, yaml_tag='!Enclosure'), name='c8fba417_2600000'), '56396fc8_3343440': SymmetricalCrossSection(width=3343440, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB90 (3/0), yaml_tag='!Enclosure'), name='56396fc8_3343440'), '56396fc8_375000': SymmetricalCrossSection(width=375000, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB90 (3/0), yaml_tag='!Enclosure'), name='56396fc8_375000'), '56396fc8_6100000': SymmetricalCrossSection(width=6100000, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB90 (3/0), yaml_tag='!Enclosure'), name='56396fc8_6100000')}, enclosure=KCellEnclosure(enclosures=LayerEnclosureCollection(enclosures=[])), library=<klayout.dbcore.Library object at 0x110438750>, factories={'taper': <function taper at 0x115f12840>, 'bend_s_bezier': <function bend_s_bezier_factory.<locals>.bend_s_bezier at 0x11058bf60>, 'bend_circular': <function bend_circular at 0x115f11080>, 'bend_euler': <function bend_euler at 0x115f11b20>, 'bend_s_euler': <function bend_s_euler_factory.<locals>.bend_s_euler at 0x113551120>, 'straight': <function straight at 0x115f83c40>, 'rotate': <function rotate at 0x1157aa2a0>, 'mirror': <function mirror at 0x1157aa3e0>, 'from_image': <function from_image at 0x115b9c680>, 'floorplan_with_block_letters': <function floorplan_with_block_letters at 0x115e88400>, 'bend_circular_heater': <function bend_circular_heater at 0x115f11260>, 'bend_euler_s': <function bend_euler_s at 0x115f11940>, 'bezier': <function bezier at 0x115f11ee0>, 'bend_s': <function bend_s at 0x115f120c0>, 'add_fiber_array_optical_south_electrical_north': <function add_fiber_array_optical_south_electrical_north at 0x115f122a0>, 'ramp': <function ramp at 0x115f12660>, 'taper_strip_to_ridge': <function taper_strip_to_ridge at 0x115f128e0>, 'taper_strip_to_ridge_trenches': <function taper_strip_to_ridge_trenches at 0x115f12b60>, 'taper_sc_nc': <function taper_sc_nc at 0x115f12ca0>, 'taper_nc_sc': <function taper_nc_sc at 0x115f12de0>, 'taper_adiabatic': <function taper_adiabatic at 0x115f13060>, 'taper_cross_section': <function taper_cross_section at 0x115e89260>, 'taper_from_csv': <function taper_from_csv at 0x115f13100>, 'taper_parabolic': <function taper_parabolic at 0x115f13240>, 'add_termination': <function add_termination at 0x115e89760>, 'add_trenches': <function add_trenches at 0x115f12f20>, 'array': <function array at 0x115f13420>, 'copy_layers': <function copy_layers at 0x115f13920>, 'extend_ports_list': <function extend_ports_list at 0x115f13a60>, 'extend_ports': <function extend_ports at 0x115f13ce0>, 'pack_doe': <function pack_doe at 0x115f4c4a0>, 'pack_doe_grid': <function pack_doe_grid at 0x115f4c5e0>, 'splitter_chain': <function splitter_chain at 0x115f4c720>, 'mzi': <function mzi at 0x115f4cb80>, 'mzi_lattice': <function mzi_lattice at 0x115f4ce00>, 'mzi_lattice_mmi': <function mzi_lattice_mmi at 0x115f4cf40>, 'mzi_pads_center': <function mzi_pads_center at 0x115f4d120>, 'mzit': <function mzit at 0x115f4d260>, 'mzit_lattice': <function mzit_lattice at 0x115f4d3a0>, 'splitter_tree': <function splitter_tree at 0x115f4cd60>, 'coupler_symmetric': <function coupler_symmetric at 0x115f4d440>, 'coupler_straight': <function coupler_straight at 0x115f4d580>, 'coupler': <function coupler at 0x115f4d6c0>, 'coupler90': <function coupler90 at 0x115f4d800>, 'coupler90bend': <function coupler90bend at 0x115f4d8a0>, 'coupler_adiabatic': <function coupler_adiabatic at 0x115f4dbc0>, 'coupler_asymmetric': <function coupler_asymmetric at  ...

# %%
# note
"""
layer 9: structure to keep
layer 11: gold deposition area
layer 12: frontside etching area
"""
# Out:
# '\nlayer 9: structure to keep\nlayer 11: gold deposition area\nlayer 12: frontside etching area\n'

# %%
# mid structure
# mid_struct = gf.Component()
# pad = gf.components.circle(radius=31, layer=(9, 0))
# gold = gf.components.circle(radius=27.5, layer=(11, 0))


# spring_path = gf.Path([(0, 30), (0, 157), (25, 157), (25, 165), (-23, 165), (-23, 173), (0, 173), (0, 300)])
# s_spring = gf.Section(width=2, layer=(9, 0))
# x_spring = gf.CrossSection(sections=[s_spring])
# spring = gf.path.extrude(spring_path, x_spring)
# for i in range(8):
#     angle = 360/8*i
#     (mid_struct << spring).rotate(angle=angle, center=(0, 0))
# mid_struct << pad
# mid_struct << gold

# mid_struct.show()
mid_struct = create_mid_structure_circle()

block << mid_struct
# Out:
# Unnamed_57: ports [], vinsts=[] info=Info() kcl=KCLayout(name='DEFAULT', layout=<klayout.dbcore.Layout object at 0x110438650>, layer_enclosures=LayerEnclosureModel(root={'c8fba417': LayerEnclosure(layer_sections={}, main_layer=12/0, yaml_tag='!Enclosure'), '56396fc8': LayerEnclosure(layer_sections={}, main_layer=SLAB90 (3/0), yaml_tag='!Enclosure'), '4fb2b992': LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure')}), cross_sections={'c8fba417_2600000': SymmetricalCrossSection(width=2600000, enclosure=LayerEnclosure(layer_sections={}, main_layer=12/0, yaml_tag='!Enclosure'), name='c8fba417_2600000'), '56396fc8_3343440': SymmetricalCrossSection(width=3343440, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB90 (3/0), yaml_tag='!Enclosure'), name='56396fc8_3343440'), '56396fc8_375000': SymmetricalCrossSection(width=375000, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB90 (3/0), yaml_tag='!Enclosure'), name='56396fc8_375000'), '56396fc8_6100000': SymmetricalCrossSection(width=6100000, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB90 (3/0), yaml_tag='!Enclosure'), name='56396fc8_6100000'), '4fb2b992_2000': SymmetricalCrossSection(width=2000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_2000')}, enclosure=KCellEnclosure(enclosures=LayerEnclosureCollection(enclosures=[])), library=<klayout.dbcore.Library object at 0x110438750>, factories={'taper': <function taper at 0x115f12840>, 'bend_s_bezier': <function bend_s_bezier_factory.<locals>.bend_s_bezier at 0x11058bf60>, 'bend_circular': <function bend_circular at 0x115f11080>, 'bend_euler': <function bend_euler at 0x115f11b20>, 'bend_s_euler': <function bend_s_euler_factory.<locals>.bend_s_euler at 0x113551120>, 'straight': <function straight at 0x115f83c40>, 'rotate': <function rotate at 0x1157aa2a0>, 'mirror': <function mirror at 0x1157aa3e0>, 'from_image': <function from_image at 0x115b9c680>, 'floorplan_with_block_letters': <function floorplan_with_block_letters at 0x115e88400>, 'bend_circular_heater': <function bend_circular_heater at 0x115f11260>, 'bend_euler_s': <function bend_euler_s at 0x115f11940>, 'bezier': <function bezier at 0x115f11ee0>, 'bend_s': <function bend_s at 0x115f120c0>, 'add_fiber_array_optical_south_electrical_north': <function add_fiber_array_optical_south_electrical_north at 0x115f122a0>, 'ramp': <function ramp at 0x115f12660>, 'taper_strip_to_ridge': <function taper_strip_to_ridge at 0x115f128e0>, 'taper_strip_to_ridge_trenches': <function taper_strip_to_ridge_trenches at 0x115f12b60>, 'taper_sc_nc': <function taper_sc_nc at 0x115f12ca0>, 'taper_nc_sc': <function taper_nc_sc at 0x115f12de0>, 'taper_adiabatic': <function taper_adiabatic at 0x115f13060>, 'taper_cross_section': <function taper_cross_section at 0x115e89260>, 'taper_from_csv': <function taper_from_csv at 0x115f13100>, 'taper_parabolic': <function taper_parabolic at 0x115f13240>, 'add_termination': <function add_termination at 0x115e89760>, 'add_trenches': <function add_trenches at 0x115f12f20>, 'array': <function array at 0x115f13420>, 'copy_layers': <function copy_layers at 0x115f13920>, 'extend_ports_list': <function extend_ports_list at 0x115f13a60>, 'extend_ports': <function extend_ports at 0x115f13ce0>, 'pack_doe': <function pack_doe at 0x115f4c4a0>, 'pack_doe_grid': <function pack_doe_grid at 0x115f4c5e0>, 'splitter_chain': <function splitter_chain at 0x115f4c720>, 'mzi': <function mzi at 0x115f4cb80>, 'mzi_lattice': <function mzi_lattice at 0x115f4ce00>, 'mzi_lattice_mmi': <function mzi_lattice_mmi at 0x115f4cf40>, 'mzi_pads_center': <function mzi_pads_center at 0x115f4d120>, 'mzit': <function mzit at 0x115f4d260>, 'mzit_lattice': <function mzit_lattice at 0x115f4d3a0>, 'splitter_tree': <function splitter_tree at 0x115f4cd60>, 'coupler_symmetric': <function coupler_symmetric at 0x115f4d440>, 'coupler_straight': <function coupler_straight at 0x115f4d580>, 'coupler': <function coupler ...

# %%
# frontside etching area
frame_size = 2600
frontside = gf.components.rectangle(size=(frame_size, frame_size), layer=(12, 0))
(block << frontside).move((-1300, -1300))

# backside etching area
backside_size = frame_size + 743.44
backside = gf.components.rectangle(size=(backside_size, backside_size), layer=(3, 0))
(block << backside).move((-backside_size/2, -backside_size/2))

# side frame etching area
# 7300um x 7300um gap between frame: 600
etch_frame = gf.components.rectangle(size=(6100, 375), layer=(3, 0))
for i in range(4):
    angle = 90 * i
    (block << etch_frame).move((-6100/2, -7300/2)).rotate(angle=angle, center=(0, 0))
# block.show()

# %%
# order
def add_order_text(order_number):
    order = gf.Component()
    for j in range(4):
        T = gf.components.text(f"WDC{order_number}", size=20, layer=(1, 0))
        order_ref = order << T
        if j == 0:
            order_ref.move((-2000, -2000))
        elif j == 1:
            order_ref.move((-2000, 2000))
        elif j == 2:
            order_ref.move((2000, -2000))
        else:
            order_ref.move((2000, 2000))
    return order
    # order.show()

# %%
# repeat
fblock = gf.Component()
block_temp = gf.Component()
block_temp << block
for i in range(1):
    if i == 0:
        block_ref = fblock << block_temp
    elif i == 1:
        block_ref = fblock << block_temp
        block_ref.move((10000, 0))
    elif i == 2:
        block_ref = fblock << block_temp
        block_ref.move((10000, 10000))
    else:
        block_ref = fblock << block_temp
        block_ref.move((0, 10000))

# %%
# boolean operation
outside = gf.boolean(A = fblock, B = fblock,  operation="not", layer1=(12, 0), layer2=(9, 0), layer=(1, 0))
cell_temp << outside

#  gold
gold = gf.boolean(A = fblock, B = fblock,  operation="not", layer1=(11, 0), layer2=(30, 0), layer=(2, 0))
cell_temp << gold
# backside etching
backside = gf.boolean(A = fblock, B = fblock,  operation="not", layer1=(3, 0), layer2=(30, 0), layer=(3, 0))
cell_temp << backside
# add marker/order
marker = gf.boolean(A = fblock, B = fblock,  operation="not", layer1=(1, 0), layer2=(30, 0), layer=(1, 0))
cell_temp << marker

def cell_web_design_circle(order_number):
    cell_web_design_circle = gf.Component()
    cell_temp_temp = gf.Component()
    order = add_order_text(order_number)
    cell_temp_temp << order
    cell_temp_temp << cell_temp
    cell_web_design_circle << cell_temp_temp
    return cell_web_design_circle
    # cell_ref.move((2500, -7500))
    # cell_web_design_circle.show()
    # cell_web_design_circle.write_gds("mesh.gds")
    # cell_web_design_circle.plot()

if __name__ == "__main__":
    cell = cell_web_design_circle(order_number=1)
    cell.show()
