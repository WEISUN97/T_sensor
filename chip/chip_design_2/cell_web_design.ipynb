# %%
import sys
# sys.path.append("/Users/bubble/Desktop/Project/Infrasound Sensor/Layout/Code/acousticsensor")
import math
import gdsfactory as gf
cell_temp = gf.Component()
# the whole chip
block = gf.Component()
# Out:
# 2026-02-11 13:29:11.622 | INFO     | kfactory.kcell:show:8777 - klive v0.3.3: Opened file '/Users/bubble/Desktop/Project/T_sensor/T_sensor/build/gds/2449257150.oas'

# %%
# web mesh
mesh_web = gf.Component()
L = 1000
w = 2
g = 48

n_horizontal = 20
for i in range(20):
    h_horizontal = 300+i*50
    L_horizontal = 2*h_horizontal*math.tan(22.5*math.pi/180)
    s_horizontal = gf.Section(width=2, layer=(9, 0))
    X_horizontal = gf.CrossSection(sections=[s_horizontal])
    p_horizontal = gf.path.straight(L_horizontal)
    c_horizontal = gf.path.extrude(p_horizontal, X_horizontal)
    (mesh_web << c_horizontal).move((-L_horizontal/2, -h_horizontal))
    (mesh_web << c_horizontal).move((-L_horizontal/2, h_horizontal)).rotate(angle=45, center=(0, 0))

n_support = 5
for i in range(n_support):
    angle = 45/4*i-22.5
    L_support_1 = 1010/math.cos(angle*math.pi/180)
    L_support_2 = 950/math.cos(angle*math.pi/180)
    s_support = gf.Section(width=2, layer=(9, 0))
    X_support = gf.CrossSection(sections=[s_support])
    p_support = gf.path.straight(L_support_1)
    c_support_1 = gf.path.extrude(p_support, X_support)
    (mesh_web << c_support_1).rotate(-90).movey(-300/math.cos(angle*math.pi/180)).rotate(angle=angle, center=(0,0))
    p_support = gf.path.straight(L_support_2)
    c_support_2 = gf.path.extrude(p_support, X_support)
    (mesh_web << c_support_2).rotate(-90).movey(-300/math.cos(angle*math.pi/180)).rotate(angle=angle+45, center=(0,0))
# circle array
for i in range(4):
    angle = 360/4*i
    (block << mesh_web).rotate(angle=angle, center=(0, 0))
# length mark
T = gf.components.text(f"L={L} b={w} gap={g}", size=50, layer=(1, 0))
(block << T).move((-375, -1500))

# block.show()
# Out:
# Unnamed_1: ports [], vinsts=[] info=Info() kcl=KCLayout(name='DEFAULT', layout=<klayout.dbcore.Layout object at 0x106488650>, layer_enclosures=LayerEnclosureModel(root={}), cross_sections={}, enclosure=KCellEnclosure(enclosures=LayerEnclosureCollection(enclosures=[])), library=<klayout.dbcore.Library object at 0x106488750>, factories={'taper': <function taper at 0x13050e840>, 'bend_s_bezier': <function bend_s_bezier_factory.<locals>.bend_s_bezier at 0x115b4ff60>, 'bend_circular': <function bend_circular at 0x13050d080>, 'bend_euler': <function bend_euler at 0x13050db20>, 'bend_s_euler': <function bend_s_euler_factory.<locals>.bend_s_euler at 0x125b71120>, 'straight': <function straight at 0x130583c40>, 'rotate': <function rotate at 0x127c7a2a0>, 'mirror': <function mirror at 0x127c7a3e0>, 'from_image': <function from_image at 0x13019c680>, 'floorplan_with_block_letters': <function floorplan_with_block_letters at 0x130388400>, 'bend_circular_heater': <function bend_circular_heater at 0x13050d260>, 'bend_euler_s': <function bend_euler_s at 0x13050d940>, 'bezier': <function bezier at 0x13050dee0>, 'bend_s': <function bend_s at 0x13050e0c0>, 'add_fiber_array_optical_south_electrical_north': <function add_fiber_array_optical_south_electrical_north at 0x13050e2a0>, 'ramp': <function ramp at 0x13050e660>, 'taper_strip_to_ridge': <function taper_strip_to_ridge at 0x13050e8e0>, 'taper_strip_to_ridge_trenches': <function taper_strip_to_ridge_trenches at 0x13050eb60>, 'taper_sc_nc': <function taper_sc_nc at 0x13050eca0>, 'taper_nc_sc': <function taper_nc_sc at 0x13050ede0>, 'taper_adiabatic': <function taper_adiabatic at 0x13050f060>, 'taper_cross_section': <function taper_cross_section at 0x130389260>, 'taper_from_csv': <function taper_from_csv at 0x13050f100>, 'taper_parabolic': <function taper_parabolic at 0x13050f240>, 'add_termination': <function add_termination at 0x130389760>, 'add_trenches': <function add_trenches at 0x13050ef20>, 'array': <function array at 0x13050f420>, 'copy_layers': <function copy_layers at 0x13050f920>, 'extend_ports_list': <function extend_ports_list at 0x13050fa60>, 'extend_ports': <function extend_ports at 0x13050fce0>, 'pack_doe': <function pack_doe at 0x1305484a0>, 'pack_doe_grid': <function pack_doe_grid at 0x1305485e0>, 'splitter_chain': <function splitter_chain at 0x130548720>, 'mzi': <function mzi at 0x130548b80>, 'mzi_lattice': <function mzi_lattice at 0x130548e00>, 'mzi_lattice_mmi': <function mzi_lattice_mmi at 0x130548f40>, 'mzi_pads_center': <function mzi_pads_center at 0x130549120>, 'mzit': <function mzit at 0x130549260>, 'mzit_lattice': <function mzit_lattice at 0x1305493a0>, 'splitter_tree': <function splitter_tree at 0x130548d60>, 'coupler_symmetric': <function coupler_symmetric at 0x130549440>, 'coupler_straight': <function coupler_straight at 0x130549580>, 'coupler': <function coupler at 0x1305496c0>, 'coupler90': <function coupler90 at 0x130549800>, 'coupler90bend': <function coupler90bend at 0x1305498a0>, 'coupler_adiabatic': <function coupler_adiabatic at 0x130549bc0>, 'coupler_asymmetric': <function coupler_asymmetric at 0x130549e40>, 'coupler_bent_half': <function coupler_bent_half at 0x13054a0c0>, 'coupler_bent': <function coupler_bent at 0x13054a200>, 'coupler_broadband': <function coupler_broadband at 0x13054a480>, 'coupler_full': <function coupler_full at 0x13054a5c0>, 'coupler_ring': <function coupler_ring at 0x13054a7a0>, 'coupler_straight_asymmetric': <function coupler_straight_asymmetric at 0x13054a8e0>, 'align_wafer': <function align_wafer at 0x13054ab60>, 'add_frame': <function add_frame at 0x13054ac00>, 'die': <function die at 0x13054ae80>, 'die_with_pads': <function die_with_pads at 0x13054afc0>, 'seal_ring': <function seal_ring at 0x13054b100>, 'seal_ring_segmented': <function seal_ring_segmented at 0x13054b240>, 'wafer': <function wafer at 0x13054b380>, 'free_propagation_region': <function free_propagation_region at 0x13054b6a0>, 'awg': <function awg at 0x13054b740>, 'd ...

# %%
# note
"""
layer 9: structure to keep
layer 11: gold deposition area
layer 12: frontside etching area
"""
# Out:
# '\nlayer 9: structure to keep\nlayer 11: gold deposition area\nlayer 12: frontside etching area\n'

# %%
# mid structure
mid_struct = gf.Component()
pad = gf.components.rectangle(size=(100, 100), layer=(9, 0))
gold = gf.components.rectangle(size=(95, 95), layer=(11, 0))

# springs
spring_single = gf.Component()
spring = gf.Component()
# vertical paths
y1 = gf.components.rectangle(size=(2, 116), layer=(9, 0))
y2 = gf.components.rectangle(size=(2, 6), layer=(9, 0))
# horizontal paths
x1 = gf.components.rectangle(size=(26, 2), layer=(9, 0))
x2 = gf.components.rectangle(size=(50, 2), layer=(9, 0))
spring_single<< y1
(spring_single<< x1).movey(116)
(spring_single<< y2).move((24, 118))
(spring_single<< x2).move(( -24, 124))
(spring_single<< y2).move((-24, 126))
(spring_single<< x1).move((-24, 132))
(spring_single<< y1).move((0, 134))

(spring << spring_single).move((-41, -300))
(spring << spring_single).move((-41, -300)).dmirror_x(0)

mid_struct << spring
(mid_struct << spring).drotate(angle=-90, center=(0,0))
(mid_struct << spring).drotate(angle=90, center=(0,0))
(mid_struct << spring).dmirror_y(0)

(mid_struct << pad).move((-50,-50))
(mid_struct << gold).move((-47.5,-47.5))

# mid_struct.show()
block << mid_struct
# Out:
# Unnamed_1: ports [], vinsts=[] info=Info() kcl=KCLayout(name='DEFAULT', layout=<klayout.dbcore.Layout object at 0x106488650>, layer_enclosures=LayerEnclosureModel(root={'4fb2b992': LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), '76156b2a': LayerEnclosure(layer_sections={}, main_layer=11/0, yaml_tag='!Enclosure')}), cross_sections={'4fb2b992_100000': SymmetricalCrossSection(width=100000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_100000'), '76156b2a_95000': SymmetricalCrossSection(width=95000, enclosure=LayerEnclosure(layer_sections={}, main_layer=11/0, yaml_tag='!Enclosure'), name='76156b2a_95000'), '4fb2b992_116000': SymmetricalCrossSection(width=116000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_116000'), '4fb2b992_2000': SymmetricalCrossSection(width=2000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_2000'), '4fb2b992_6000': SymmetricalCrossSection(width=6000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_6000'), '4fb2b992_26000': SymmetricalCrossSection(width=26000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_26000'), '4fb2b992_50000': SymmetricalCrossSection(width=50000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_50000')}, enclosure=KCellEnclosure(enclosures=LayerEnclosureCollection(enclosures=[])), library=<klayout.dbcore.Library object at 0x106488750>, factories={'taper': <function taper at 0x13050e840>, 'bend_s_bezier': <function bend_s_bezier_factory.<locals>.bend_s_bezier at 0x115b4ff60>, 'bend_circular': <function bend_circular at 0x13050d080>, 'bend_euler': <function bend_euler at 0x13050db20>, 'bend_s_euler': <function bend_s_euler_factory.<locals>.bend_s_euler at 0x125b71120>, 'straight': <function straight at 0x130583c40>, 'rotate': <function rotate at 0x127c7a2a0>, 'mirror': <function mirror at 0x127c7a3e0>, 'from_image': <function from_image at 0x13019c680>, 'floorplan_with_block_letters': <function floorplan_with_block_letters at 0x130388400>, 'bend_circular_heater': <function bend_circular_heater at 0x13050d260>, 'bend_euler_s': <function bend_euler_s at 0x13050d940>, 'bezier': <function bezier at 0x13050dee0>, 'bend_s': <function bend_s at 0x13050e0c0>, 'add_fiber_array_optical_south_electrical_north': <function add_fiber_array_optical_south_electrical_north at 0x13050e2a0>, 'ramp': <function ramp at 0x13050e660>, 'taper_strip_to_ridge': <function taper_strip_to_ridge at 0x13050e8e0>, 'taper_strip_to_ridge_trenches': <function taper_strip_to_ridge_trenches at 0x13050eb60>, 'taper_sc_nc': <function taper_sc_nc at 0x13050eca0>, 'taper_nc_sc': <function taper_nc_sc at 0x13050ede0>, 'taper_adiabatic': <function taper_adiabatic at 0x13050f060>, 'taper_cross_section': <function taper_cross_section at 0x130389260>, 'taper_from_csv': <function taper_from_csv at 0x13050f100>, 'taper_parabolic': <function taper_parabolic at 0x13050f240>, 'add_termination': <function add_termination at 0x130389760>, 'add_trenches': <function add_trenches at 0x13050ef20>, 'array': <function array at 0x13050f420>, 'copy_layers': <function copy_layers at 0x13050f920>, 'extend_ports_list': <function extend_ports_list at 0x13050fa60>, 'extend_ports': <function extend_ports at 0x13050fce0>, 'pack_doe': <function pack_doe at 0x1305484a0>, 'pack_doe_grid': <function pack_doe_grid at 0x1305485e0>, 'splitter_chain': <function splitter_chain at 0x130548720>, 'mzi': <function mzi at 0x130548b80>, 'mzi_lattice': <function mzi_lattice at 0x130548e00>, 'mzi_lattice_mmi': <function mzi_lattice_mmi at 0x130548f40>, 'mzi_pads_center': <function mzi_pads_center at 0x130549120>, 'mzit': <function mzit at 0x130549260>, 'mzit_lattice': <function mzit_lattice at 0x1305493a0>, 'splitter_tree': <function spli ...

# %%
# frontside etching area
frame_size = 2600
frontside = gf.components.rectangle(size=(frame_size, frame_size), layer=(12, 0))
(block << frontside).move((-1300, -1300))

# backside etching area
backside_size = frame_size + 743.44
backside = gf.components.rectangle(size=(backside_size, backside_size), layer=(3, 0))
(block << backside).move((-backside_size/2, -backside_size/2))

# side frame etching area
# 7300um x 7300um gap between frame: 600
etch_frame = gf.components.rectangle(size=(6100, 375), layer=(3, 0))
for i in range(4):
    angle = 90 * i
    (block << etch_frame).move((-6100/2, -7300/2)).rotate(angle=angle, center=(0, 0))
# block.show()

# %%
# order
def add_order_text(order_number):
    order = gf.Component()
    for j in range(4):
        T = gf.components.text(f"WD{order_number}", size=20, layer=(1, 0))
        order_ref = order << T
        if j == 0:
            order_ref.move((-2000, -2000))
        elif j == 1:
            order_ref.move((-2000, 2000))
        elif j == 2:
            order_ref.move((2000, -2000))
        else:
            order_ref.move((2000, 2000))
    return order
    # order.show()

# %%
# repeat
fblock = gf.Component()
block_temp = gf.Component()
block_temp << block
for i in range(1):
    if i == 0:
        block_ref = fblock << block_temp
    elif i == 1:
        block_ref = fblock << block_temp
        block_ref.move((10000, 0))
    elif i == 2:
        block_ref = fblock << block_temp
        block_ref.move((10000, 10000))
    else:
        block_ref = fblock << block_temp
        block_ref.move((0, 10000))

# %%
# boolean operation
outside = gf.boolean(A = fblock, B = fblock,  operation="not", layer1=(12, 0), layer2=(9, 0), layer=(1, 0))
cell_temp << outside

#  gold
gold = gf.boolean(A = fblock, B = fblock,  operation="not", layer1=(11, 0), layer2=(30, 0), layer=(2, 0))
cell_temp << gold
# backside etching
backside = gf.boolean(A = fblock, B = fblock,  operation="not", layer1=(3, 0), layer2=(30, 0), layer=(3, 0))
cell_temp << backside
# add marker/order
marker = gf.boolean(A = fblock, B = fblock,  operation="not", layer1=(1, 0), layer2=(30, 0), layer=(1, 0))
cell_temp << marker

def cell_web_design(order_number):
    cell_web_design = gf.Component()
    cell_temp_temp = gf.Component()
    order = add_order_text(order_number)
    cell_temp_temp << order
    cell_temp_temp << cell_temp
    cell_web_design << cell_temp_temp
    return cell_web_design
    # cell_ref.move((2500, -7500))
    # cell_web_design.show()
    # cell_web_design.write_gds("mesh.gds")
    # cell_web_design.plot()

if __name__ == "__main__":
    cell = cell_web_design(order_number=1)
    cell.show()
