# %%
import sys
# sys.path.append("/Users/bubble/Desktop/Project/Infrasound Sensor/Layout/Code/acousticsensor")

import gdsfactory as gf
cell_temp = gf.Component()
# the whole chip
block = gf.Component()
# Out:
# 2026-02-05 19:17:03.245 | INFO     | kfactory.kcell:show:8777 - klive v0.3.3: Opened file '/Users/bubble/Desktop/Project/T_sensor/T_sensor/build/gds/3102935058.oas'

# %%
# square mesh
L = [1000]
b = [500]
g = [48]
w = 2


mesh_rect = gf.Component()
origin = (0, 0)

for i in range(len(L)):
    for j in range(len(b)):
        column = int(b[j] / (w + g[i]))
        row = int(L[j] / (w + g[i]))
        for n in range(row):
            r = gf.components.rectangle(size=(b[i]+w, w), layer=(9, 0))
            (mesh_rect << r).movey((n+1) * (w + g[i])-w)
        for m in range(column+1):
            r = gf.components.rectangle(size=(w, L[i]), layer=(9, 0))
            (mesh_rect << r).movex(m * (w + g[i]))

    # length mark
    T = gf.components.text(f"L={L[i]} b={b[i]} gap={g[i]}", size=50, layer=(1, 0))
    T_ref = block << T
    T_ref.move((-350, -1500))

# %%
# note
"""
layer 9: structure to keep
layer 11: gold deposition area
layer 12: frontside etching area
"""
# Out:
# '\nlayer 9: structure to keep\nlayer 11: gold deposition area\nlayer 12: frontside etching area\n'

# %%
# web mesh
mesh_web = gf.Component()
sections = []

n_horizontal = 18
for i in range(n_horizontal):
    offset = i * 50
    s = gf.Section(width=2, offset=offset, layer=(9, 0))
    sections.append(s)

x_circle = gf.CrossSection(sections=tuple(sections))

p_circle = gf.path.arc(50)
# Combine the Path and the cross-section.
b_circle = gf.path.extrude(p_circle, cross_section=x_circle)    
(mesh_web << b_circle).move((0, -50))


support = gf.components.rectangle(size=(2, (g[0]+w)*(n_horizontal-1)), layer=(9, 0))
for i in range(2):
    angle = 90 / 3 * (i+1) + 180
    (mesh_web << support).move((0, 50)).rotate(angle=angle, center=(0, 0))
# mesh_web.show()

# %%
# web combination
web = gf.Component()
web_temp = gf.Component()
(web_temp << mesh_rect).move((-(b[0]+w)/2, -L[0]-300))
(web_temp << mesh_web).move(((b[0]+w)/2, -301+50))
for i in range(4):
    angle = 90 * i
    (web << web_temp).rotate(angle=angle, center=(0, 0))
block << web
# Out:
# Unnamed_1: ports [], vinsts=[] info=Info() kcl=KCLayout(name='DEFAULT', layout=<klayout.dbcore.Layout object at 0x10ee40350>, layer_enclosures=LayerEnclosureModel(root={'4fb2b992': LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure')}), cross_sections={'4fb2b992_2000': SymmetricalCrossSection(width=2000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_2000'), '4fb2b992_502000': SymmetricalCrossSection(width=502000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_502000'), '4fb2b992_1000000': SymmetricalCrossSection(width=1000000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_1000000'), '4fb2b992_850000': SymmetricalCrossSection(width=850000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_850000')}, enclosure=KCellEnclosure(enclosures=LayerEnclosureCollection(enclosures=[])), library=<klayout.dbcore.Library object at 0x10ee40450>, factories={'taper': <function taper at 0x1163d68e0>, 'bend_s_bezier': <function bend_s_bezier_factory.<locals>.bend_s_bezier at 0x111c9c040>, 'bend_circular': <function bend_circular at 0x1163d5120>, 'bend_euler': <function bend_euler at 0x1163d5bc0>, 'bend_s_euler': <function bend_s_euler_factory.<locals>.bend_s_euler at 0x1148ed1c0>, 'straight': <function straight at 0x116443ce0>, 'rotate': <function rotate at 0x115daa340>, 'mirror': <function mirror at 0x115daa480>, 'from_image': <function from_image at 0x1160f87c0>, 'floorplan_with_block_letters': <function floorplan_with_block_letters at 0x1163504a0>, 'bend_circular_heater': <function bend_circular_heater at 0x1163d5300>, 'bend_euler_s': <function bend_euler_s at 0x1163d59e0>, 'bezier': <function bezier at 0x1163d5f80>, 'bend_s': <function bend_s at 0x1163d6160>, 'add_fiber_array_optical_south_electrical_north': <function add_fiber_array_optical_south_electrical_north at 0x1163d6340>, 'ramp': <function ramp at 0x1163d6700>, 'taper_strip_to_ridge': <function taper_strip_to_ridge at 0x1163d6980>, 'taper_strip_to_ridge_trenches': <function taper_strip_to_ridge_trenches at 0x1163d6c00>, 'taper_sc_nc': <function taper_sc_nc at 0x1163d6d40>, 'taper_nc_sc': <function taper_nc_sc at 0x1163d6e80>, 'taper_adiabatic': <function taper_adiabatic at 0x1163d7100>, 'taper_cross_section': <function taper_cross_section at 0x116351300>, 'taper_from_csv': <function taper_from_csv at 0x1163d71a0>, 'taper_parabolic': <function taper_parabolic at 0x1163d72e0>, 'add_termination': <function add_termination at 0x116351800>, 'add_trenches': <function add_trenches at 0x1163d6fc0>, 'array': <function array at 0x1163d74c0>, 'copy_layers': <function copy_layers at 0x1163d79c0>, 'extend_ports_list': <function extend_ports_list at 0x1163d7b00>, 'extend_ports': <function extend_ports at 0x1163d7d80>, 'pack_doe': <function pack_doe at 0x116410540>, 'pack_doe_grid': <function pack_doe_grid at 0x116410680>, 'splitter_chain': <function splitter_chain at 0x1164107c0>, 'mzi': <function mzi at 0x116410c20>, 'mzi_lattice': <function mzi_lattice at 0x116410ea0>, 'mzi_lattice_mmi': <function mzi_lattice_mmi at 0x116410fe0>, 'mzi_pads_center': <function mzi_pads_center at 0x1164111c0>, 'mzit': <function mzit at 0x116411300>, 'mzit_lattice': <function mzit_lattice at 0x116411440>, 'splitter_tree': <function splitter_tree at 0x116410e00>, 'coupler_symmetric': <function coupler_symmetric at 0x1164114e0>, 'coupler_straight': <function coupler_straight at 0x116411620>, 'coupler': <function coupler at 0x116411760>, 'coupler90': <function coupler90 at 0x1164118a0>, 'coupler90bend': <function coupler90bend at 0x116411940>, 'coupler_adiabatic': <function coupler_adiabatic at 0x116411c60>, 'coupler_asymmetric': <function coupler_asymmetric at 0x116411ee0>, 'coupler_bent_half': <function coupler_bent_half at 0x116412160>, 'coupler_bent': <function coupler_bent at 0x1164122a0>, ' ...

# %%
# mid structure
mid_struct = gf.Component()
pad = gf.components.rectangle(size=(100, 100), layer=(9, 0))
gold = gf.components.rectangle(size=(95, 95), layer=(11, 0))

# springs
spring_single = gf.Component()
spring = gf.Component()
# vertical paths
y1 = gf.components.rectangle(size=(2, 116), layer=(9, 0))
y2 = gf.components.rectangle(size=(2, 6), layer=(9, 0))
# horizontal paths
x1 = gf.components.rectangle(size=(26, 2), layer=(9, 0))
x2 = gf.components.rectangle(size=(50, 2), layer=(9, 0))
spring_single<< y1
(spring_single<< x1).movey(116)
(spring_single<< y2).move((24, 118))
(spring_single<< x2).move(( -24, 124))
(spring_single<< y2).move((-24, 126))
(spring_single<< x1).move((-24, 132))
(spring_single<< y1).move((0, 134))

(spring << spring_single).move((-41, -300))
(spring << spring_single).move((-41, -300)).dmirror_x(0)

mid_struct << spring
(mid_struct << spring).drotate(angle=-90, center=(0,0))
(mid_struct << spring).drotate(angle=90, center=(0,0))
(mid_struct << spring).dmirror_y(0)

(mid_struct << pad).move((-50,-50))
(mid_struct << gold).move((-47.5,-47.5))

# mid_struct.show()
block << mid_struct
# Out:
# Unnamed_1: ports [], vinsts=[] info=Info() kcl=KCLayout(name='DEFAULT', layout=<klayout.dbcore.Layout object at 0x10ee40350>, layer_enclosures=LayerEnclosureModel(root={'4fb2b992': LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), '76156b2a': LayerEnclosure(layer_sections={}, main_layer=11/0, yaml_tag='!Enclosure')}), cross_sections={'4fb2b992_2000': SymmetricalCrossSection(width=2000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_2000'), '4fb2b992_502000': SymmetricalCrossSection(width=502000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_502000'), '4fb2b992_1000000': SymmetricalCrossSection(width=1000000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_1000000'), '4fb2b992_850000': SymmetricalCrossSection(width=850000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_850000'), '4fb2b992_100000': SymmetricalCrossSection(width=100000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_100000'), '76156b2a_95000': SymmetricalCrossSection(width=95000, enclosure=LayerEnclosure(layer_sections={}, main_layer=11/0, yaml_tag='!Enclosure'), name='76156b2a_95000'), '4fb2b992_116000': SymmetricalCrossSection(width=116000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_116000'), '4fb2b992_6000': SymmetricalCrossSection(width=6000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_6000'), '4fb2b992_26000': SymmetricalCrossSection(width=26000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_26000'), '4fb2b992_50000': SymmetricalCrossSection(width=50000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_50000')}, enclosure=KCellEnclosure(enclosures=LayerEnclosureCollection(enclosures=[])), library=<klayout.dbcore.Library object at 0x10ee40450>, factories={'taper': <function taper at 0x1163d68e0>, 'bend_s_bezier': <function bend_s_bezier_factory.<locals>.bend_s_bezier at 0x111c9c040>, 'bend_circular': <function bend_circular at 0x1163d5120>, 'bend_euler': <function bend_euler at 0x1163d5bc0>, 'bend_s_euler': <function bend_s_euler_factory.<locals>.bend_s_euler at 0x1148ed1c0>, 'straight': <function straight at 0x116443ce0>, 'rotate': <function rotate at 0x115daa340>, 'mirror': <function mirror at 0x115daa480>, 'from_image': <function from_image at 0x1160f87c0>, 'floorplan_with_block_letters': <function floorplan_with_block_letters at 0x1163504a0>, 'bend_circular_heater': <function bend_circular_heater at 0x1163d5300>, 'bend_euler_s': <function bend_euler_s at 0x1163d59e0>, 'bezier': <function bezier at 0x1163d5f80>, 'bend_s': <function bend_s at 0x1163d6160>, 'add_fiber_array_optical_south_electrical_north': <function add_fiber_array_optical_south_electrical_north at 0x1163d6340>, 'ramp': <function ramp at 0x1163d6700>, 'taper_strip_to_ridge': <function taper_strip_to_ridge at 0x1163d6980>, 'taper_strip_to_ridge_trenches': <function taper_strip_to_ridge_trenches at 0x1163d6c00>, 'taper_sc_nc': <function taper_sc_nc at 0x1163d6d40>, 'taper_nc_sc': <function taper_nc_sc at 0x1163d6e80>, 'taper_adiabatic': <function taper_adiabatic at 0x1163d7100>, 'taper_cross_section': <function taper_cross_section at 0x116351300>, 'taper_from_csv': <function taper_from_csv at 0x1163d71a0>, 'taper_parabolic': <function taper_parabolic at 0x1163d72e0>, 'add_termination': <function add_termination at 0x116351800>, 'add_trenches': <function add_trenches at 0x1163d6fc0>, 'array': <function array at 0x1163d74c0>, 'copy_layers': <function copy_layers at 0x1163d79c0>, 'extend_ports_list': <function extend_ports_list at 0x1163d7b00>, 'extend_ports': <function extend_ports at 0x1163d7d80>, 'pack_do ...

# %%
# frontside etching area
frame_size = 2600
frontside = gf.components.rectangle(size=(frame_size, frame_size), layer=(12, 0))
(block << frontside).move((-1300, -1300))

# backside etching area
backside_size = frame_size + 743.44
backside = gf.components.rectangle(size=(backside_size, backside_size), layer=(3, 0))
(block << backside).move((-backside_size/2, -backside_size/2))

# side frame etching area
# 7300um x 7300um gap between frame: 600
etch_frame = gf.components.rectangle(size=(6100, 375), layer=(3, 0))
for i in range(4):
    angle = 90 * i
    (block << etch_frame).move((-6100/2, -7300/2)).rotate(angle=angle, center=(0, 0))
# block.show()
# Out:
# Unnamed_1: ports ['e1', 'e2', 'e3', 'e4'], vinsts=[] info=Info() kcl=KCLayout(name='DEFAULT', layout=<klayout.dbcore.Layout object at 0x10ee40350>, layer_enclosures=LayerEnclosureModel(root={'4fb2b992': LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), '76156b2a': LayerEnclosure(layer_sections={}, main_layer=11/0, yaml_tag='!Enclosure'), 'c8fba417': LayerEnclosure(layer_sections={}, main_layer=12/0, yaml_tag='!Enclosure'), '56396fc8': LayerEnclosure(layer_sections={}, main_layer=SLAB90 (3/0), yaml_tag='!Enclosure')}), cross_sections={'4fb2b992_2000': SymmetricalCrossSection(width=2000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_2000'), '4fb2b992_502000': SymmetricalCrossSection(width=502000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_502000'), '4fb2b992_1000000': SymmetricalCrossSection(width=1000000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_1000000'), '4fb2b992_850000': SymmetricalCrossSection(width=850000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_850000'), '4fb2b992_100000': SymmetricalCrossSection(width=100000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_100000'), '76156b2a_95000': SymmetricalCrossSection(width=95000, enclosure=LayerEnclosure(layer_sections={}, main_layer=11/0, yaml_tag='!Enclosure'), name='76156b2a_95000'), '4fb2b992_116000': SymmetricalCrossSection(width=116000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_116000'), '4fb2b992_6000': SymmetricalCrossSection(width=6000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_6000'), '4fb2b992_26000': SymmetricalCrossSection(width=26000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_26000'), '4fb2b992_50000': SymmetricalCrossSection(width=50000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_50000'), 'c8fba417_2600000': SymmetricalCrossSection(width=2600000, enclosure=LayerEnclosure(layer_sections={}, main_layer=12/0, yaml_tag='!Enclosure'), name='c8fba417_2600000'), '56396fc8_3343440': SymmetricalCrossSection(width=3343440, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB90 (3/0), yaml_tag='!Enclosure'), name='56396fc8_3343440')}, enclosure=KCellEnclosure(enclosures=LayerEnclosureCollection(enclosures=[])), library=<klayout.dbcore.Library object at 0x10ee40450>, factories={'taper': <function taper at 0x1163d68e0>, 'bend_s_bezier': <function bend_s_bezier_factory.<locals>.bend_s_bezier at 0x111c9c040>, 'bend_circular': <function bend_circular at 0x1163d5120>, 'bend_euler': <function bend_euler at 0x1163d5bc0>, 'bend_s_euler': <function bend_s_euler_factory.<locals>.bend_s_euler at 0x1148ed1c0>, 'straight': <function straight at 0x116443ce0>, 'rotate': <function rotate at 0x115daa340>, 'mirror': <function mirror at 0x115daa480>, 'from_image': <function from_image at 0x1160f87c0>, 'floorplan_with_block_letters': <function floorplan_with_block_letters at 0x1163504a0>, 'bend_circular_heater': <function bend_circular_heater at 0x1163d5300>, 'bend_euler_s': <function bend_euler_s at 0x1163d59e0>, 'bezier': <function bezier at 0x1163d5f80>, 'bend_s': <function bend_s at 0x1163d6160>, 'add_fiber_array_optical_south_electrical_north': <function add_fiber_array_optical_south_electrical_north at 0x1163d6340>, 'ramp': <function ramp at 0x1163d6700>, 'taper_strip_to_ridge': <function taper_strip_to_ridge at 0x1163d6980>, 'taper_strip_to_ridge_trenches': <function taper_strip_to_ridge_trenches at 0x1163d6c00>, 'taper_sc_nc': <function taper_sc_nc at 0x1163d6d40>, 'taper_nc_sc': <function taper_nc_sc at 0x1163d6e80>, 'taper_adiabatic': <function taper_adiabatic a ...

# %%
# order
order = gf.Component()
text_array = []
for i in range(4):
    text_array.append(gf.Component())

for i in range(4):
    T = gf.components.text(f"MDL{i+1}", size=20, layer=(1, 0))
    for j in range(4):
        order_ref = text_array[i] << T
        if j == 0:
            order_ref.move((1000, 1000))
        elif j == 1:
            order_ref.move((1000, 4000))
        elif j == 2:
            order_ref.move((4000, 1000))
        else:
            order_ref.move((4000, 4000))
    text_array_ref = order << text_array[i]
    if i == 0:
        pass
    elif i == 1:
        text_array_ref.move((10000, 0))
    elif i == 2:
        text_array_ref.move((0, 10000))
    else:
        text_array_ref.move((10000, 10000))

# %%
# repeat
fblock = gf.Component()
block_temp = gf.Component()
(block_temp << block).move((2500, 2500))
for i in range(4):
    if i == 0:
        block_ref = fblock << block_temp
    elif i == 1:
        block_ref = fblock << block_temp
        block_ref.move((10000, 0))
    elif i == 2:
        block_ref = fblock << block_temp
        block_ref.move((10000, 10000))
    else:
        block_ref = fblock << block_temp
        block_ref.move((0, 10000))

# %%
# boolean operation
outside = gf.boolean(A = fblock, B = fblock,  operation="not", layer1=(12, 0), layer2=(9, 0), layer=(1, 0))
cell_temp << outside

#  gold
gold = gf.boolean(A = fblock, B = fblock,  operation="not", layer1=(11, 0), layer2=(30, 0), layer=(2, 0))
cell_temp << gold
# backside etching
backside = gf.boolean(A = fblock, B = fblock,  operation="not", layer1=(3, 0), layer2=(30, 0), layer=(3, 0))
cell_temp << backside
# add marker/order
marker = gf.boolean(A = fblock, B = fblock,  operation="not", layer1=(1, 0), layer2=(30, 0), layer=(1, 0))
cell_temp << marker
cell_temp << order
# frame
frame1 = gf.components.rectangle(size=(15000, 15000), layer=(20, 0))
frame2 = gf.components.rectangle(size=(20000, 20000), layer=(21, 0))
frame2_ref = cell_temp << frame2
frame2_ref.move((-2500, -2500))
cell_temp << frame1

cell_mesh_design_less = gf.Component()
cell_ref = cell_mesh_design_less << cell_temp
cell_ref.move((2500, -7500))
cell_mesh_design_less.show()
# cell_mesh_design_less.write_gds("mesh.gds")
# cell_mesh_design_less.plot()
